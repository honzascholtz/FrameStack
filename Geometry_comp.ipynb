# %%
import FrameStack as FrS
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Ribble Edurance SL Disc - size Large

# %%
path = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_Endurance_L.txt'
f,ax = FrS.plot_geometry(path)

f.savefig('/Users/jansen/Code/Cycling/Bike_geometry/Figures/Ribble_Endurance_L.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Seat → bar tip (3-D)
#  In-plane: 685 mm
#  + ½ bar:  714 mm

# %% [markdown]
# # Merida Silex 400 - Size Medium

# %%
path = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Merida_Silex400_M.txt'
f,ax = FrS.plot_geometry(path)

f.savefig('/Users/jansen/Code/Cycling/Bike_geometry/Figures/Merida_Silex400_M.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Seat → bar tip (3-D)
#  In-plane: 663 mm
#  + ½ bar:  693 mm

# %% [markdown]
# # Comparing geometries of multiple bikes

# %%
path = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt'
path2 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_allroadSLR_L.txt'
path3 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Canyon_Endurace_M.txt'
path4 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Cervelo_Caledonia_56.txt'

paths = [path, path2, path3]#, path4]
names = ['Ribble Endurance SL R', 'Ribble Allroad SL R', 'Canyon Endurace M']# 'Cervelo Caledonia 56',]

def main():
    f,ax = FrS.plot_comparison(paths, names = names)
    f.savefig('/Users/jansen/Code/Cycling/Bike_geometry/Figures/Comp_bikes.png', dpi=300, bbox_inches='tight')


    plt.show()

if __name__ == '__main__':
    main()
# Out:
# ['/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt', '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_allroadSLR_L.txt', '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Canyon_Endurace_M.txt'] ['Ribble Endurance SL R', 'Ribble Allroad SL R', 'Canyon Endurace M'] ['blue', 'orange', 'green']

# %%
path = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt'
path2 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_S.txt'


paths = [path, path2]
names = ['Ribble Endurance SL Large', 'Ribble Endurance Small']

def main():
    f,ax = FrS.plot_comparison(paths, names = names)

    plt.show()

if __name__ == '__main__':
    main()
# Out:
# ['/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt', '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_S.txt'] ['Ribble Endurance SL Large', 'Ribble Endurance Small'] ['blue', 'orange']

# %% [markdown]
# # Comparing Gravel and aeroish road bike

# %%
path = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt'
path2 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Merida_Silex400_M.txt'


paths = [path, path2]
names = ['Ribble Endurance SL Large', 'Merida Silex400 M']

def main():
    f,ax = FrS.plot_comparison(paths, names = names)
    f.savefig('/Users/jansen/Code/Cycling/Bike_geometry/Figures/Comp_bikes2.png', dpi=300, bbox_inches='tight')
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# ['/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt', '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Merida_Silex400_M.txt'] ['Ribble Endurance SL Large', 'Merida Silex400 M'] ['blue', 'orange']

# %% [markdown]
# # Rosa Shave

# %%
path = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt'
path2 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Rose_Shave_ML.txt'


paths = [path, path2]
names = ['Ribble Endurance SL Large', 'Rose Shave ML']

def main():
    f,ax = FrS.plot_geometry(path2)

    f,ax = FrS.plot_comparison(paths, names = names)
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Seat → bar tip (3-D)
#  In-plane: 692 mm
#  + ½ bar:  719 mm
# ['/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt', '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Rose_Shave_ML.txt'] ['Ribble Endurance SL Large', 'Rose Shave ML'] ['blue', 'orange']
