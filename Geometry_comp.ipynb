# %%
from Geometry import Geometry
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# ─────────────────────────────────────────────────────────────────────────────
# Entry point
# ─────────────────────────────────────────────────────────────────────────────

def main():
    path = '/Users/jansen/Documents/Cycling/Ribble_endurance_L.txt'
    path2 = '/Users/jansen/Documents/Cycling/Ribble_allroadSLR_L.txt'
    path3 = '/Users/jansen/Documents/Cycling/Cervelo_Caledonia_56.txt'
    path4 = '/Users/jansen/Documents/Cycling/Canyon_Endurace_M.txt'
    
    G = Geometry(path)
    G2 = Geometry(path2)
    G3 = Geometry(path3)
    G4 = Geometry(path4)

    fig, ax = plt.subplots(figsize=(12, 6))
    fig = G.plot_comp(fig, ax, path, color='blue',)
    fig = G.plot_comp(fig, ax, path2, color='orange')
    fig = G.plot_comp(fig, ax, path3, color='green')
    fig = G.plot_comp(fig, ax, path4, color='purple')

    ax.plot([], [], color='blue', label='Ribble Endurance SL R')
    ax.plot([], [], color='orange', label='Ribble Allroad SL R')
    ax.plot([], [], color='green', label='Cervelo Caledonia 56')
    ax.plot([], [], color='purple', label='Canyon Endurace M')
    from matplotlib.legend_handler import HandlerTuple
    order = np.array([-1,-2,-3,-4], dtype=int)
            
    h, l = ax.get_legend_handles_labels()



    ax.legend([h[i] for i in order], [l[i] for i in order],fontsize=15, ncol=2,
            loc='upper left', columnspacing=0.5,)

    plt.show()


if __name__ == '__main__':
    main()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/jansen/Library/Mobile Documents/com~apple~CloudDocs/Code/Cycling/Bike_geom.py:550: UserWarning: The figure layout has changed to tight
