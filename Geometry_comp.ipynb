# %%
import Geometry as G
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_Endurance_L.txt'
f,ax = G.plot_geometry(path)

f.savefig('/Users/jansen/Code/Cycling/Bike_geometry/Figures/Ribble_Endurance_L.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Seat → bar tip (3-D)
#  In-plane: 690 mm
#  + ½ bar:  718 mm

# %% [markdown]
# # Comparing geomtries of multiple bikes

# %%
path = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt'
path2 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_allroadSLR_L.txt'
path3 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Cervelo_Caledonia_56.txt'
path4 = '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Canyon_Endurace_M.txt'

paths = [path, path2, path3, path4]
names = ['Ribble Endurance SL R', 'Ribble Allroad SL R', 'Cervelo Caledonia 56', 'Canyon Endurace M']

def main():
    f,ax = G.plot_comparison(paths, names = names)
    f.savefig('/Users/jansen/Code/Cycling/Bike_geometry/Figures/Comp_bikes.png', dpi=300, bbox_inches='tight')


    plt.show()

if __name__ == '__main__':
    main()
# Out:
# ['/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_endurance_L.txt', '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Ribble_allroadSLR_L.txt', '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Cervelo_Caledonia_56.txt', '/Users/jansen/Code/Cycling/Bike_geometry/Geometry_files/Canyon_Endurace_M.txt'] ['Ribble Endurance SL R', 'Ribble Allroad SL R', 'Cervelo Caledonia 56', 'Canyon Endurace M'] ['blue', 'orange', 'green', 'purple']
# /Users/jansen/Library/Mobile Documents/com~apple~CloudDocs/Code/Cycling/Bike_geometry/Geometry.py:582: UserWarning: The figure layout has changed to tight
